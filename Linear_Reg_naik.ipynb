# %% [markdown]
# Linear Regression

# %%
from sklearn.datasets import fetch_openml
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = fetch_openml(name= "boston", version=1, as_frame=True)

# X = boston.data
# y = boston.target

# print(X.head())
# print(y.head())

dataset= pd.DataFrame(df.data)

# %%
dataset.columns = df.feature_names
dataset.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
# independent features and dependent features

X = dataset
y = df.target

y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
# train test split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.31, random_state=34)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 32    1.38799   0.0   8.14    0  0.538  5.950  82.0  3.9900   4  307.0
# 210   0.17446   0.0  10.59    1  0.489  5.960  92.1  3.8771   4  277.0
# 438  13.67810   0.0  18.10    0  0.740  5.935  87.9  1.8206  24  666.0
# 278   0.07978  40.0   6.41    0  0.447  6.482  32.1  4.1403   4  254.0
# 223   0.61470   0.0   6.20    0  0.507  6.618  80.8  3.2721   8  307.0
# ..        ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 246   0.33983  22.0   5.86    0  0.431  6.108  34.9  8.0555   7  330.0
# 361   3.83684   0.0  18.10    0  0.770  6.251  91.1  2.2955  24  666.0
# 490   0.20746   0.0  27.74    0  0.609  5.093  98.0  1.8226   4  711.0
# 122   0.09299   0.0  25.65    0  0.581  5.961  92.9  2.0869   2  188.0
# 417  25.94060   0.0  18.10    0  0.679  5.304  89.1  1.6475  24  666.0
#
#      PTRATIO       B  LSTAT
# 32      21.0  232.60  27.71
# 210     18.6  393.25  17.27
# 438     20.2   68.95  34.02
# 278     17.6  396.90   7.19
# 223     17.4  396.90   7.60
# ..       ...     ...    ...
# 246     19.1  390.18   9.16
# 361     20.2  350.65  14.19
# 490     20.1  318.43  29.68
# 122     19.1  378.09  17.93
# 417     20.2  127.36  26.64
#
# [349 rows x 13 columns]

# %%
# Linear regression
# standardizing the dataset

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test )

# %%
X_train
# Out:
# array([[-0.26709601, -0.49169581, -0.43744512, ...,  1.18253789,
#         -1.31423076,  2.10133274],
#        [-0.40892911, -0.49169581, -0.07662453, ...,  0.05825442,
#          0.40929707,  0.65751548],
#        [ 1.16932858, -0.49169581,  1.02940103, ...,  0.80777674,
#         -3.06994398,  2.97398474],
#        ...,
#        [-0.40507218, -0.49169581,  2.44911959, ...,  0.76093159,
#         -0.39340665,  2.37377718],
#        [-0.41845103, -0.49169581,  2.14131754, ...,  0.29248014,
#          0.24665355,  0.74879128],
#        [ 2.6025262 , -0.49169581,  1.02940103, ...,  0.80777674,
#         -2.44329437,  1.9533553 ]])

# %%
# inverse transform 

scaler.inverse_transform(X_train)
# Out:
# array([[1.38799e+00, 0.00000e+00, 8.14000e+00, ..., 2.10000e+01,
#         2.32600e+02, 2.77100e+01],
#        [1.74460e-01, 0.00000e+00, 1.05900e+01, ..., 1.86000e+01,
#         3.93250e+02, 1.72700e+01],
#        [1.36781e+01, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         6.89500e+01, 3.40200e+01],
#        ...,
#        [2.07460e-01, 0.00000e+00, 2.77400e+01, ..., 2.01000e+01,
#         3.18430e+02, 2.96800e+01],
#        [9.29900e-02, 0.00000e+00, 2.56500e+01, ..., 1.91000e+01,
#         3.78090e+02, 1.79300e+01],
#        [2.59406e+01, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         1.27360e+02, 2.66400e+01]])

# %%
from sklearn.linear_model import LinearRegression

# cross validation

from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()
regression.fit(X_train, y_train)


mse = cross_val_score(regression, X_train, y_train, scoring="neg_mean_squared_error", cv=10 )

# %%
np.mean(mse)
# Out:
# -26.397578379781045

# %%
# prediction

reg_pred = regression.predict(X_test)

# %%
reg_pred
# Out:
# array([ 7.57990682, 22.92805997,  3.43988056, 29.85274596, 30.09941619,
#         8.24751517, 12.20690925, 18.08127013, 21.17254878, 36.29219708,
#        20.76059551, 12.36361939, 32.65591641, 41.48551854, 21.84089043,
#        34.00524851, 29.70875988, 20.0167842 , 18.11094977, 16.55090896,
#        20.17183472, 18.85940955, 12.80137252, 26.75325324, 29.28967928,
#        20.73954042, 15.77282619, 38.58384111, 25.9581738 , 24.3704993 ,
#        18.91651756, 39.96596863, 13.9250828 , 28.27438863, 32.23833418,
#        27.92177351, 23.21262539, 19.2814307 , 21.87367443, 22.78189075,
#        21.22826918, 20.81279399, 29.46449004, 23.23755844, 17.4272267 ,
#        42.59434064, 23.17121333,  9.85393019, 18.14146373, 40.222266  ,
#        20.96249518, 37.6407405 , 16.69314518, 24.22400264, 42.29169635,
#        28.40560412, 19.4830135 , 27.7932673 , 24.21682173, 18.72065869,
#        30.69527502, 27.58089446, 17.35887053, 12.80563657, 20.27018585,
#        19.47975871, 25.33785387, 26.54829325, 27.80180054,  9.16038331,
#        33.02191593, 18.08603971, 20.75783639, 26.5629817 , 17.85980182,
#        24.65007321, 26.53606308, 11.81340721, 21.00244821, 27.36055755,
#        38.94172684, 13.66049922,  1.86596992, 14.58136059, 10.57458895,
#        16.0033137 , 35.21883868, 23.37450171, 27.97939512,  7.22394408,
#        24.00734165, 24.89891658, 27.50717146, 34.03378635, 28.46379188,
#        34.00954073, 22.88681132,  6.90604947, 14.28953866, 25.65137658,
#        22.92710858, 18.31836271, 21.47978599, 18.0818112 , 37.4945561 ,
#        35.5657146 , 28.22648239, 26.26115744, 23.61140331,  8.7716377 ,
#        14.91134311, 27.2679955 , 23.22319678, 19.66305873, 22.36020093,
#        31.16351469, 18.37416336, 26.62901667, 25.68412518,  7.76973795,
#        28.41801752, 20.59812146, 32.55111862,  8.29585473, 29.21164517,
#        23.7521799 , 13.1709358 , 13.47010285, 26.80915441,  5.77081276,
#        25.68308435, 20.95539042, 14.55112629, 19.24375985, 11.53522894,
#        31.01571441, 23.05096308, 28.93499729, 30.98542965, 34.1472394 ,
#        16.07936834, 16.1105561 , 18.38730709, 36.68220808, 35.12524234,
#        19.73241383, 17.47288984, 29.30437401, 13.58325658, 32.41115477,
#        18.96109039, 19.83934231, 21.48330217, 22.71019087, 27.44005628,
#        26.66820005, 23.15138403, 31.25521522, 28.1153719 , 26.3900862 ,
#        23.47384387, 18.46660473, 33.90570732,  9.88818396, 17.56648799,
#        22.26845772, 10.09017699, 17.8949244 , 27.93230564, 35.77153399,
#        -3.72800947, 37.53817854, 13.30711526, 32.10044016, 17.71155703,
#        31.55555287, 34.1176559 , 29.38109314, 21.89075528, 20.04359665,
#        17.31676827, 21.45862488, 34.0362699 , 38.61953281, 32.63685995,
#        19.29734943, 26.47969234, 23.18514864, 19.59261883, 22.65541883,
#        17.32427925, 28.7213247 , 24.10842108, 25.74539428, 15.61423301,
#        12.52915224, 16.39028781, 30.3898815 , 16.80258342, 17.66048996,
#        14.11916067, 19.60089135, 17.28489798, 20.07688507,  8.79111423,
#        24.32275523, 26.25982325, 24.38960921, 20.69725714, 22.84348764,
#        21.5399153 , 14.68741905, 28.16652889, 17.61376261, 21.8066755 ,
#        19.58500292, 32.15924747, 19.40461685, 35.78244092, 21.14234373,
#        21.22194794, 34.77554308, 14.61090504, 13.35978719, 19.8498306 ,
#        19.35367352, 25.48367911, 25.30552746, 16.01733461, 17.45195388,
#        14.13732893, 15.25054101, 32.03426804, 23.43159764, 23.42302417,
#        20.43420439, 21.60503946, 20.35022114, 13.33814972, 34.61195992,
#        20.1349485 , 17.357642  , 21.47329089, 23.47751552, 22.5961553 ,
#        19.77622221, 13.89314888, 14.76872514, 34.02035919, 20.64953511,
#        12.44538648, 10.9524024 ,  9.32883638, 14.9685003 , 30.62019079,
#        22.68059133, 30.13625785, 31.46579152, 29.8187138 , 25.46612331,
#        25.57686661, 24.38170945, 19.74361223, 25.0508891 , 22.7979843 ,
#        19.72203329, 22.15276292, 24.4241006 , 20.07925756, 20.80382356,
#        17.43037377, 16.26908699, 23.05291101,  3.65203216, 20.83245087,
#        34.64569414, 21.89957899, 27.86473447, 23.53177304, 24.13185707,
#        33.75471616, 13.48028533, 21.69648477, 26.78760526, 21.38835812,
#        12.43357482, 21.15263511, 28.92403243, 22.28683197, 18.80998932,
#        27.19956405, 24.30701102, 31.40702043, 37.71939456, 20.52799804,
#        24.05576007, 22.82437223, 26.4598917 , 37.76967089, 30.19203267,
#        21.80524787, 22.4844873 , 33.27927163, 41.5246921 , 15.99825338,
#        34.56309127, 37.48827032, 25.38807664, 20.65533702, 26.07727829,
#        23.18344591, 17.11743012, 13.9463175 , 20.34754083, 17.40445708,
#        17.07146774, 24.1780704 , 23.81109987, 30.20429163, 34.37255415,
#        18.98377257, 18.56876647, 12.64245144,  7.83965958, 36.92451357,
#        24.16567648, 24.5775239 , 35.30206034, 20.11031733,  6.14810537,
#        19.47357086, 27.38183415, 21.53328524, 30.27530386, 20.91782934,
#        15.35640369, 34.42186902, 23.35975615, 27.85571717, 16.6719389 ,
#        22.35085323, 23.94329167, 24.65095425, 27.53959729, 20.15076812,
#        19.28681567,  3.90046426, 21.19611785,  7.07460193])

# %%
import seaborn as sns
sns.displot(reg_pred - y_test, kind="kde")

# %%
from sklearn.metrics import r2_score
score = r2_score(reg_pred, y_test)

# %%
score
# Out:
# 0.6272382471486238
